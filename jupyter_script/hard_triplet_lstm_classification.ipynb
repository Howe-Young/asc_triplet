# %% [markdown]
# ## Baseline of 3-convolutional layer and lstm classification
# - **network**
#     - embedding:
#     ```conv(5x5)->maxpool(2x2)->conv(5x5)->maxpool(2x2)->conv(3x3)->bi-lstm(32 hidden units)```
#     - classifier:
#     ```linear(64, 10)```
#     - loss function: ```CrossEntropyLoss```

# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
from experiment import hard_triplet_baseline

# %%
kwargs = {
        'device': '2',
        'lr': 1e-3,
        'n_epochs': 100,
        'n_classes': 10,
        'n_samples': 12,
        'margin': 0.3,
        'log_interval': 50
    }

# %%
kwargs
# Out:
# {'device': '2',
#  'log_interval': 50,
#  'lr': 0.001,
#  'margin': 0.3,
#  'n_classes': 10,
#  'n_epochs': 100,
#  'n_samples': 12}

# %%
hard_triplet_baseline.hard_triplet_baseline_exp(**kwargs)
# Out:
# 10080it [00:00, 307924.02it/s]
# 10080it [00:00, 205046.73it/s]
# 10080it [00:00, 488594.66it/s]
# [LOGGING]: Loading train a of shape:  (6122, 40, 500)
# [LOGGING]: Loading test a of shape:  (2518, 40, 500)
# Train: [0/6122 (0%)]	Loss: 0.251502	Average nonzero triplets: 660.0
# Train: [6000/6122 (98%)]	Loss: 0.307016	Average nonzero triplets: 651.8823529411765
# Epoch: 1/100. Train set: Average loss: 0.3059.	Average nonzero triplets: 651.8823529411765
# Epoch: 1/100. Validation set: Average loss: 0.2949	Average nonzero triplets: 659.9
# Train: [0/6122 (0%)]	Loss: 0.273519	Average nonzero triplets: 660.0
# Train: [6000/6122 (98%)]	Loss: 0.308887	Average nonzero triplets: 646.2156862745098
# Epoch: 2/100. Train set: Average loss: 0.3082.	Average nonzero triplets: 646.2156862745098
# Epoch: 2/100. Validation set: Average loss: 0.3573	Average nonzero triplets: 651.95
# Train: [0/6122 (0%)]	Loss: 0.354191	Average nonzero triplets: 618.0
# ...
