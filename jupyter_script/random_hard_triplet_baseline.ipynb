# %% [markdown]
# ### Online hard triplet baseline
# Randomly select hard triplets.

# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
from experiment.hard_triplet_baseline import hard_triplet_baseline_exp

# %%
kwargs = {
        'device': '2',
        'lr': 1e-3,
        'n_epochs': 300,
        'n_classes': 10,
        'n_samples': 12,
        'margin': 0.3,
        'log_interval': 50
    }

# %%
kwargs
# Out:
# {'device': '2',
#  'log_interval': 50,
#  'lr': 0.001,
#  'margin': 0.3,
#  'n_classes': 10,
#  'n_epochs': 300,
#  'n_samples': 12}

# %%
hard_triplet_baseline_exp(**kwargs)
# Out:
# 10080it [00:00, 186368.32it/s]
# 10080it [00:00, 475008.25it/s]
# 10080it [00:00, 246840.44it/s]
# [LOGGING]: Loading train a of shape:  (6122, 40, 500)
# [LOGGING]: Loading test a of shape:  (2518, 40, 500)
# Train: [0/6122 (0%)]	Loss: 0.415711	Average nonzero triplets: 660.0
# Train: [6000/6122 (98%)]	Loss: 0.389037	Average nonzero triplets: 659.9215686274509
# Epoch: 1/300. Train set: Average loss: 0.3896.	Average nonzero triplets: 659.9215686274509
# Epoch: 1/300. Validation set: Average loss: 0.2832	Average nonzero triplets: 659.1
# Train: [0/6122 (0%)]	Loss: 0.312200	Average nonzero triplets: 660.0
# Train: [6000/6122 (98%)]	Loss: 0.303126	Average nonzero triplets: 648.2352941176471
# Epoch: 2/300. Train set: Average loss: 0.3033.	Average nonzero triplets: 648.2352941176471
# Epoch: 2/300. Validation set: Average loss: 0.3241	Average nonzero triplets: 653.05
# Train: [0/6122 (0%)]	Loss: 0.309550	Average nonzero triplets: 630.0
# ...
