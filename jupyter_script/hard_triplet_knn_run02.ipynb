# %% [markdown]
# ## Randomly select hard triplets and using kNN verification

# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
from experiment.hard_triplet_with_knn import hard_triplet_with_knn_exp

# %%
kwargs = {
        'ckpt_prefix': 'Run02',
        'device': '0',
        'lr': 1e-3,
        'embedding_epochs': 150,
        'n_epochs': 50,
        'n_classes': 10,
        'n_samples': 12,
        'margin': 0.5,
        'log_interval': 80,
        'k': 3
    }

# %%
hard_triplet_with_knn_exp(**kwargs)
# Out:
# [CheckPoint:]acc not improved on 0.624
