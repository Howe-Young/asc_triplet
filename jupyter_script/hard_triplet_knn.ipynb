# %% [markdown]
# ## Randomly select hard triplets and using kNN verification

# %%
import sys
sys.path.append('..')
# %load_ext autoreload
# %autoreload 2

# %%
from experiment.hard_triplet_with_knn import hard_triplet_with_knn_exp

# %%
kwargs = {
        'ckpt_prefix': 'Run01',
        'device': '0',
        'lr': 1e-3,
        'embedding_epochs': 50,
        'n_epochs': 50,
        'n_classes': 10,
        'n_samples': 12,
        'margin': 0.5,
        'log_interval': 80,
        'k': 3
    }

# %%
hard_triplet_with_knn_exp(**kwargs)
# Out:
# [CheckPoint:]delete file /data/yanghao/domain_adapt/asc_triplet/experiment/ckpt/hard_triplet_with_knn_exp/Run01,embedding_net_shallow,Epoch_48,acc_0.635425.tar
# [CheckPoint:]saved model to /data/yanghao/domain_adapt/asc_triplet/experiment/ckpt/hard_triplet_with_knn_exp/Run01,embedding_net_shallow,Epoch_50,acc_0.638999.tar
# created
